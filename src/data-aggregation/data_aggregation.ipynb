# %% [markdown]
# ## Authentication

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# ## Initializing BigQuery client

# %%
from google.cloud import bigquery

project_id = "icoads-time-series-analysis"
client = bigquery.Client(project=project_id)

# %% [markdown]
# ## Data Copy from Open dataset to project workspace

# %%
query = """
CREATE OR REPLACE TABLE `icoads-time-series-analysis.icoads_data.icoads_raw_aggregated` AS
SELECT * FROM `bigquery-public-data.noaa_icoads.icoads_core_2001_2004`
UNION ALL
SELECT *
FROM `bigquery-public-data.noaa_icoads.icoads_core_*`
WHERE _TABLE_SUFFIX BETWEEN '2005' AND '2017'
"""

query_job = client.query(query)
query_job.result()
print("Table created successfully!")
# Out:
# Table created successfully!

# %% [markdown]
# ## Testing table availability

# %%
dataset_ref = client.dataset(dataset_id='icoads_data')
tables = list(client.list_tables(dataset_ref))
for table in tables:
  print(table.table_id)
# Out:
# icoads_raw_aggregated

# %%
df = client.query('''
SELECT sea_surface_temp FROM `icoads-time-series-analysis.icoads_data.icoads_raw_aggregated`
WHERE year = 2005
''').to_dataframe()

display(df)
# Out:
#           sea_surface_temp
# 0                     25.6
# 1                     19.5
# 2                     19.9
# 3                     23.5
# 4                     24.7
# ...                    ...
# 14242731              30.0
# 14242732              30.0
# 14242733              30.0
# 14242734              30.0
# 14242735              30.0
#
# [14242736 rows x 1 columns]

# %%
df = client.query('''
SELECT sea_surface_temp FROM `icoads-time-series-analysis.icoads_data.icoads_raw_aggregated`
''').to_dataframe()

display(df)
# Out:
#            sea_surface_temp
# 0                      27.6
# 1                      26.5
# 2                      22.4
# 3                       1.7
# 4                      29.2
# ...                     ...
# 358429085              29.0
# 358429086              29.0
# 358429087              29.0
# 358429088              29.0
# 358429089              29.0
#
# [358429090 rows x 1 columns]
